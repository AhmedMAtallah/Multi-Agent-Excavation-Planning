# %%
# Importing the necessary classes from the src directory
import importlib
from src.planner import Planner
importlib.reload(src.planner)
# Out:
# <module 'src.planner' from '/home/aatallah/volley/multi_agent_digging_planning/src/planner.py'>

# %%
# Initialize two robots at different starting positions with different priorities
robot1 = Robot(Point(0, 0), "Robot 1", priority=2)  # Higher priority
robot2 = Robot(Point(9, 9), "Robot 2", priority=1)  # Lower priority

# Define the grid size and obstacles
grid_size = 10
obstacles = {
    Point(0, 2), Point(0, 6), Point(1, 1), Point(1, 3), Point(3, 2), 
    Point(6, 1), Point(7, 3), Point(7, 9), Point(9, 1)
}

# Define the drop-off locations
drop_off_locations = [Point(0, 9), Point(5, 5)]

# Initialize the central planner with the robots, grid size, and drop-off locations
central_planner = Planner([robot1, robot2], grid_size, drop_off_locations, obstacles)

# Add some dig locations
central_planner.add_dig_location(Point(1, 7))
central_planner.add_dig_location(Point(7, 4))
central_planner.add_dig_location(Point(8, 1))

central_planner

# Assign tasks to robots and calculate the completion time
central_planner.assign_tasks()
estimated_time = central_planner.get_estimated_completion_time()
print(f"Estimated completion time: {estimated_time} ticks")

# Plot the robots' paths
central_planner.plot_paths()

# Generate and plot the grids at different stages
central_planner.generate_plots()

# Display the detailed path log for each robot
for robot in [robot1, robot2]:
    print(f"{robot.name} Path Log: {' -> '.join(robot.path_log)}")
# Out:
# Added dig location at 1, 7
# Added dig location at 7, 4
# Added dig location at 8, 1
# Robot 2 moved to position 8, 9
# Robot 2 moved to position 8, 8
# Robot 2 moved to position 7, 8
# Robot 2 moved to position 7, 7
# Robot 2 moved to position 7, 6
# Robot 2 moved to position 7, 5
# Robot 2 moved to position 7, 4
# Robot 2 dug at position 7 4
# Robot 2 moved to position 6, 4
# Robot 2 moved to position 6, 5
# Robot 2 offloaded at drop-off location
# Robot 1 moved to position 1, 0
# Robot 1 moved to position 2, 0
# Robot 1 moved to position 2, 1
# Robot 1 moved to position 2, 2
# Robot 1 moved to position 2, 3
# Robot 1 moved to position 2, 4
# Robot 1 moved to position 1, 4
# Robot 1 moved to position 1, 5
# Robot 1 moved to position 1, 6
# Robot 1 moved to position 1, 7
# Robot 1 dug at position 1 7
# Robot 1 moved to position 1, 8
# Robot 1 moved to position 1, 9
# Robot 1 offloaded at drop-off location
# Robot 2 moved to position 6, 4
# Robot 2 moved to position 6, 3
# Robot 2 moved to position 6, 2
# Robot 2 moved to position 7, 2
# Robot 2 moved to position 7, 1
# Robot 2 moved to position 8, 1
# Robot 2 dug at position 8 1
# Robot 2 moved to position 7, 1
# Robot 2 moved to position 7, 2
# Robot 2 moved to position 6, 2
# Robot 2 moved to position 6, 3
# Robot 2 moved to position 6, 4
# Robot 2 moved to position 6, 5
# Robot 2 offloaded at drop-off location
# Estimated completion time: 39 ticks
# Robot 1 Path Log: (0,0) -> (1,0) -> (2,0) -> (2,1) -> (2,2) -> (2,3) -> (2,4) -> (1,4) -> (1,5) -> (1,6) -> (1,7) -> dig -> (1,8) -> (1,9) -> drop off (1)
# Robot 2 Path Log: (9,9) -> (8,9) -> (8,8) -> (7,8) -> (7,7) -> (7,6) -> (7,5) -> (7,4) -> dig -> (6,4) -> (6,5) -> drop off (1) -> (6,4) -> (6,3) -> (6,2) -> (7,2) -> (7,1) -> (8,1) -> dig -> (7,1) -> (7,2) -> (6,2) -> (6,3) -> (6,4) -> (6,5) -> drop off (2)

# %%
from src.planner import CentralPlanner
from src.robot import Robot
from src.point import Point

robot1 = Robot(Point(0, 0), "Robot 1", priority=1)
central_planner = CentralPlanner([robot1], grid_size=10, drop_off_locations=[Point(5, 5)], obstacles=set())

print(central_planner.get_adjacent_position(Point(5, 5), Point(4, 4)))
# Out:
# <src.point.Point object at 0x7ff880f974f0>
